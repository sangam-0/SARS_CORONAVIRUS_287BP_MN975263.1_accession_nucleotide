# %% [markdown]
# <a href="https://colab.research.google.com/github/sangam-0/SARS_CORONAVIRUS_287BP_MN975263.1_accession_nucleotide/blob/main/SARS_CORONAVIRUS_287BP_MN975263_1_accession_nucleotide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic Library
import pandas as pd # for data manipulation
import numpy as np # for calculation(math)
import matplotlib.pyplot as plt # for graphs
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/SARS_CORONAVIRUS_287BP_MN975263.1_accession_nucleotide.csv")

# %%
df
# Out:
#     Details  Accession          Release_Date  \
# 0       NaN   LR757995  2020-02-01T00:00:00Z
# 1       NaN   LR757998  2020-02-01T00:00:00Z
# 2       NaN   LR757997  2020-02-01T00:00:00Z
# 3       NaN   LR757996  2020-02-01T00:00:00Z
# 4       NaN  NC_045512  2020-01-13T00:00:00Z
# ..      ...        ...                   ...
# 74      NaN   MT019533  2020-02-05T00:00:00Z
# 75      NaN   MT019531  2020-02-05T00:00:00Z
# 76      NaN   MT019529  2020-02-05T00:00:00Z
# 77      NaN   MT019532  2020-02-05T00:00:00Z
# 78      NaN   MT019530  2020-02-05T00:00:00Z
#
#                                               Species            Genus  \
# 0   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 1   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 2   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 3   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# ...

# %%
df.columns
# Out:
# Index(['Details', 'Accession', 'Release_Date', 'Species', 'Genus', 'Family',
#        'Length', 'Nuc._Completeness', 'Genotype', 'Genome_Region', 'Segment',
#        'Geo_Location', 'Host', 'Isolation_Source', 'Collection_Date',
#        'BioSample', 'GenBank_Title'],
#       dtype='object')

# %%
df.Species.unique()
# Out:
# array(['Severe acute respiratory syndrome-related coronavirus'],
#       dtype=object)

# %%
df.Family.value_counts()
# Out:
# Family
# Coronaviridae    79
# Name: count, dtype: int64

# %%
df.Genus.value_counts()
# Out:
# Genus
# Betacoronavirus    79
# Name: count, dtype: int64

# %%
df.Length.value_counts()
# Out:
# Length
# 29882    11
# 107       7
# 294       6
# 290       5
# 287       5
# 562       4
# 29878     4
# 29903     4
# 357       3
# 322       2
# 29891     2
# 29899     2
# 29870     2
# 29881     2
# 29883     2
# 29872     1
# 29388     1
# 29852     1
# 29857     1
# 29825     1
# 29854     1
# 29866     1
# 29868     1
# 29847     1
# 29833     1
# 29848     1
# 29879     1
# 29838     1
# 29893     1
# 182       1
# 29858     1
# 29890     1
# 29889     1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Details              79
# Accession             0
# Release_Date          0
# Species               0
# Genus                 0
# Family                0
# Length                0
# Nuc._Completeness    43
# Genotype             79
# Genome_Region        79
# Segment              79
# Geo_Location          4
# Host                  4
# Isolation_Source     22
# Collection_Date       4
# BioSample            75
# GenBank_Title         0
# dtype: int64

# %%
df.Genotype.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.Genome_Region.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.Host.value_counts()
# Out:
# Host
# Homo sapiens    75
# Name: count, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-36-168575042.py in <cell line: 0>()
# ----> 1 df.GenBank_Title.unique_value()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'unique_value'
